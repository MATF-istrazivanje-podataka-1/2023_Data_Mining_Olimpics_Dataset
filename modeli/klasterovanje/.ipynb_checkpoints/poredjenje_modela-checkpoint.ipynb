# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import joblib
import seaborn as sns

# %%
X, y = joblib.load('../../preprocesiranje/clustering_data.joblib')

# %%
kmeans, bkm, silhouettes_km, silhouettes_bkm = joblib.load('KMean_BisectingKmeans.joblib')
ac, dbscan, silhouettes_ac, silhouettes_dbscan = joblib.load('Agglomerative_DBSCAN.joblib')

# %%
X.head()
# Out:
#    Sex       Age    Height    Weight       NOC  Games     Sport
# 0  0.0  0.226415  0.552083  0.291005  0.180995    0.0  0.111111
# 1  0.0  0.207547  0.447917  0.185185  0.180995    0.0  0.481481
# 2  1.0  0.169811  0.604167  0.301587  0.633484    1.0  0.777778
# 3  1.0  0.169811  0.604167  0.301587  0.633484    1.0  0.777778
# 4  1.0  0.245283  0.604167  0.301587  0.633484    1.0  0.777778

# %%
X.drop(columns=['NOC', 'Games'], inplace=True)

# %%
models = [kmeans, bkm, ac, dbscan]

# %%
models
# Out:
# [KMeans(n_clusters=2, n_init='auto', random_state=22),
#  BisectingKMeans(init='k-means++', n_clusters=2, random_state=22),
#  AgglomerativeClustering(linkage='single', metric='euclidean'),
#  DBSCAN(eps=0.2)]

# %%
from sklearn.metrics import silhouette_score

# %%
plt.figure(figsize=(5, 5))
plt.plot(range(2, 8), silhouettes_km, label='KMeans', marker='o')
plt.plot(range(2, 8), silhouettes_bkm, label='Bisecting KMeans', marker='o')
plt.plot(range(2, 8), silhouettes_ac, label='Agglomerative', marker='o')
# plt.plot(range(2, 8), sil_score_dbscan, label='DBSCAN', marker='o')

plt.xlabel('Number of clusters')
plt.ylabel('Silhouette Score')
plt.title('Silhouette Score for Optimal k')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# Svi modeli rade najbolje kad podatke dele u 2 klastera. Sa porastom klastera pove

# %%
eps = [0.1, 0.2, 0.3]
plt.plot(eps, silhouettes_dbscan, marker = 'o')
plt.title('DBSCAN')
plt.xlabel('Epslon')
plt.ylabel('Silhouette')
plt.show()
